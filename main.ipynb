# %% [markdown]
# # Types of routing

# %% [markdown]
# ## Map Initialisation

# %%
import folium
import folium.plugins as plugins

# Center coordinates for the map
center_coordinates = [53.36486137451511, -1.8160056925378616]  # Edale

tiles = "https://api.os.uk/maps/raster/v1/zxy/Leisure_27700/{z}/{x}/{y}.png?key=GGF16a7QH0WAQEkXEXqCwHwxLp0aoMAL"
tiles_mapbox = "https://api.mapbox.com/styles/v1/mapbox/outdoors-v12/tiles/{z}/{x}/{y}?access_token=pk.eyJ1IjoiZGFuLWxlZTc2IiwiYSI6ImNsaXJ4d3N3azE3M3Mza28xdnVmdGxwczcifQ.j0THIt59Yt7D6qG1WKXTPg"
tiles_mapbox2 = "https://api.mapbox.com/v4/dan-lee76.Outdoors/{z}/{x}/{y}.png?access_token=pk.eyJ1IjoiZGFuLWxlZTc2IiwiYSI6ImNsaXJ4d3N3azE3M3Mza28xdnVmdGxwczcifQ.j0THIt59Yt7D6qG1WKXTPg"
tile_backup = "opentopomap"

# Initialize the map using OS Maps as the default tiles
m = folium.Map(location=center_coordinates, zoom_start=13, max_zoom=20, min_zoom=0, attr="© Ordnance Survey")

folium.TileLayer(
    name="Mapbox Outdoors",
    tiles="https://api.mapbox.com/styles/v1/mapbox/outdoors-v12/tiles/{z}/{x}/{y}?access_token=pk.eyJ1IjoiZGFuLWxlZTc2IiwiYSI6ImNsaXJ4d3N3azE3M3Mza28xdnVmdGxwczcifQ.j0THIt59Yt7D6qG1WKXTPg",
    attr="© Mapbox",
    overlay=False,
    control=True,
    show=False,
).add_to(m)

folium.TileLayer(
    name="OS Maps Road",
    tiles="https://api.os.uk/maps/raster/v1/zxy/Outdoor_3857/{z}/{x}/{y}.png?key=GGF16a7QH0WAQEkXEXqCwHwxLp0aoMAL",
    attr="© Ordnance Survey",
    overlay=False,
    control=True,
    show=False,
).add_to(m)

# folium.TileLayer(
#     name="OS Maps Lesiure",
#     tiles="https://api.os.uk/maps/raster/v1/zxy/Leisure_27700/{z}/{x}/{y}.png?key=GGF16a7QH0WAQEkXEXqCwHwxLp0aoMAL",
#     attr="© Ordnance Survey",
#     overlay=False,
#     control=True,
#     crs="EPSG27700",
# ).add_to(m)

folium.TileLayer(
    name="OpenTopoMap",
    tiles="https://a.tile.opentopomap.org/{z}/{x}/{y}.png",
    attr="© OpenTopoMap",
    overlay=False,
    control=True,
    show=True,
).add_to(m)

folium.GeoJson(
    data="route_buffer.geojson",
    name="GeoJSON",
    overlay=True,
    control=True,
    show=False,
).add_to(m)

folium.plugins.ScrollZoomToggler().add_to(m)

folium.LayerControl().add_to(m)

# %% [markdown]
# # Circular

# %% [markdown]
# ## GA

# %% [markdown]
# ### Code

# %%
import GA
coords = GA.generate_route()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import GA
#       2 coords = GA.generate_route()
#
# File c:\Users\Dan-L\Documents\University\diss\dissertation-backend\GA.py:1
# ----> 1 import osmnx as ox
#       2 import networkx as nx
#       3 import random
#
# File c:\Users\Dan-L\scoop\apps\miniconda3\24.7.1-0\Lib\site-packages\osmnx\__init__.py:3
#       1 """OSMnx init."""
# ----> 3 from ._api import *  # noqa: F401, F403
#       4 from ._version import __version__  # noqa: F401
#
# File c:\Users\Dan-L\scoop\apps\miniconda3\24.7.1-0\Lib\site-packages\osmnx\_api.py:5
#       2 """Expose most common parts of public API directly in package namespace."""
#       4 from . import speed
# ----> 5 from .bearing import add_edge_bearings
#       6 from .bearing import orientation_entropy
#       7 from .convert import graph_from_gdfs
#
# File c:\Users\Dan-L\scoop\apps\miniconda3\24.7.1-0\Lib\site-packages\osmnx\bearing.py:8
#       5 import networkx as nx
#       6 import numpy as np
# ----> 8 from . import plot
#       9 from . import projection
#      11 # scipy is an optional dependency for entropy calculation
#
# File c:\Users\Dan-L\scoop\apps\miniconda3\24.7.1-0\Lib\site-packages\osmnx\plot.py:12
#      10 from . import bearing
#      11 from . import convert
# ---> 12 from . import graph
#      13 from . import projection
#      14 from . import settings
#
# File c:\Users\Dan-L\scoop\apps\miniconda3\24.7.1-0\Lib\site-packages\osmnx\graph.py:17
#      14 from shapely.geometry import MultiPolygon
#      15 from shapely.geometry import Polygon
# ---> 17 from . import _overpass
#      18 from . import distance
#      19 from . import geocoder
#
# File c:\Users\Dan-L\scoop\apps\miniconda3\24.7.1-0\Lib\site-packages\osmnx\_overpass.py:9
#       6 from warnings import warn
#       8 import numpy as np
# ----> 9 import requests
#      10 from requests.exceptions import ConnectionError
#      12 from . import _downloader
#
# File c:\Users\Dan-L\scoop\apps\miniconda3\24.7.1-0\Lib\site-packages\requests\__init__.py:164
#     151 from . import packages, utils
#     152 from .__version__ import (
#     153     __author__,
#     154     __author_email__,
#    (...)
#     162     __version__,
#     163 )
# --> 164 from .api import delete, get, head, options, patch, post, put, request
#     165 from .exceptions import (
#     166     ConnectionError,
#     167     ConnectTimeout,
#    (...)
#     175     URLRequired,
#     176 )
#     177 from .models import PreparedRequest, Request, Response
#
# File c:\Users\Dan-L\scoop\apps\miniconda3\24.7.1-0\Lib\site-packages\requests\api.py:11
#       1 """
#       2 requests.api
#       3 ~~~~~~~~~~~~
#    (...)
#       8 :license: Apache2, see LICENSE for more details.
#       9 """
# ---> 11 from . import sessions
#      14 def request(method, url, **kwargs):
#      15     """Constructs and sends a :class:`Request <Request>`.
#      16
#      17     :param method: method for the new :class:`Request` object: ``GET``, ``OPTIONS``, ``HEAD``, ``POST``, ``PUT``, ``PATCH``, or ``DELETE``.
#    (...)
#      52       <Response [200]>
#      53     """
#
# File c:\Users\Dan-L\scoop\apps\miniconda3\24.7.1-0\Lib\site-packages\requests\sessions.py:15
#      12 from datetime import timedelta
#      14 from ._internal_utils import to_native_string
# ---> 15 from .adapters import HTTPAdapter
#      16 from .auth import _basic_auth_str
#      17 from .compat import Mapping, cookielib, urljoin, urlparse
#
# File c:\Users\Dan-L\scoop\apps\miniconda3\24.7.1-0\Lib\site-packages\requests\adapters.py:81
#      78     import ssl  # noqa: F401
#      80     _preloaded_ssl_context = create_urllib3_context()
# ---> 81     _preloaded_ssl_context.load_verify_locations(
#      82         extract_zipped_paths(DEFAULT_CA_BUNDLE_PATH)
#      83     )
#      84 except ImportError:
#      85     # Bypass default SSLContext creation when Python
#      86     # interpreter isn't built with the ssl module.
#      87     _preloaded_ssl_context = None
#
# KeyboardInterrupt:

# %%
folium.PolyLine(
    locations=coords,
    color="#FF0000",
    weight=5,
    tooltip="GA",
    opacity=0.5,
).add_to(m)

# %% [markdown]
# ### Outcome

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa8c2d6083519e76f44de95d0579dba1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;style&gt;
#                 #scroll_zoom_toggler_0311398778e5219fdde309335dc3b6f4 {
#                     position:absolute;
#                     width:35px;
#                     bottom:10px;
#                     height:35px;
#                     left:10px;
#                     background-color:#fff;
#                     text-align:center;
#                     line-height:35px;
#                     vertical-align: middle;
#                     }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa8c2d6083519e76f44de95d0579dba1&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;scroll_zoom_toggler_0311398778e5219fdde309335dc3b6f4&quot;
#                  alt=&quot;scroll&quot;
#                  src=&quot;https://cdnjs.cloudflare.com/ajax/libs/ionicons/2.0.1/png/512/arrow-move.png&quot;
#                  style=&quot;z-index: 999999&quot;
#                  onclick=&quot;map_aa8c2d6083519e76f44de95d0579dba1.toggleScroll()&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa8c2d6083519e76f44de95d0579dba1 = L.map(
#                 &quot;map_aa8c2d6083519e76f44de95d0579dba1&quot;,
#                 {
#                     center: [53.36486137451511, -1.8160056925378616],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa09509a6f7008adefcefa418ab869d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fa09509a6f7008adefcefa418ab869d5.addTo(map_aa8c2d6083519e76f44de95d0579dba1);
#
#
#             var tile_layer_e020180b2f271787127ad83ce0c23bdd = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/outdoors-v12/tiles/{z}/{x}/{y}?access_token=pk.eyJ1IjoiZGFuLWxlZTc2IiwiYSI6ImNsaXJ4d3N3azE3M3Mza28xdnVmdGxwczcifQ.j0THIt59Yt7D6qG1WKXTPg&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             var tile_layer_8cc145a64ceb3febca33899c804ad590 = L.tileLayer(
#                 &quot;https://api.os.uk/maps/raster/v1/zxy/Outdoor_3857/{z}/{x}/{y}.png?key=GGF16a7QH0WAQEkXEXqCwHwxLp0aoMAL&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             var tile_layer_07b79e7990031ce97b0a898d4f061550 = L.tileLayer(
#                 &quot;https://a.tile.opentopomap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 OpenTopoMap&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_07b79e7990031ce97b0a898d4f061550.addTo(map_aa8c2d6083519e76f44de95d0579dba1);
#
#
#
#         function geo_json_5fadff57680f8e6d86dcc02b78fc9579_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5fadff57680f8e6d86dcc02b78fc9579 = L.geoJson(null, {
#                 onEachFeature: geo_json_5fadff57680f8e6d86dcc02b78fc9579_onEachFeature,
#
#         });
#
#         function geo_json_5fadff57680f8e6d86dcc02b78fc9579_add (data) {
#             geo_json_5fadff57680f8e6d86dcc02b78fc9579
#                 .addData(data);
#         }
#             geo_json_5fadff57680f8e6d86dcc02b78fc9579_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-1.818934671254997, 53.34142034903661], [-1.830488834572843, 53.34434684208792], [-1.830872034572843, 53.34463794208793], [-1.833789901239506, 53.34723817121106], [-1.834035301239507, 53.34749397121106], [-1.833301828788945, 53.38284170123951], [-1.818193709752948, 53.38252820475518], [-1.819188955991268, 53.38896018656338], [-1.818634455991268, 53.38904598656338], [-1.814784975947575, 53.38933998582319], [-1.814597175947575, 53.389339785823196], [-1.813656723186319, 53.389321088246135], [-1.806578823186319, 53.38904708824613], [-1.806644736085071, 53.387344442603535], [-1.792897423017739, 53.384369357989975], [-1.787086497854863, 53.38018881362697], [-1.782999934397857, 53.37840066687511], [-1.782463268651951, 53.367763771503206], [-1.782275895410569, 53.3665725153481], [-1.78084283238307, 53.365690140794406], [-1.778939227897911, 53.36723262852288], [-1.778087287798819,

# %% [markdown]
# # Point-to-point routing

# %% [markdown]
# ## A-Star with arcs

# %% [markdown]
# 1. Creates an arc between points A and B, of the target distance (a star between the points)
# 2. Create a buffer around the arc, currently target distance * 2.5%
# 3. For each intersection within the boundary, calculate a route between them A -> b -> B
# 4. Pick closest route to distance
#
# Time: <7 Seconds (All Routes)
#
# Pros: Quick, consistent results
# Cons: Doesn't always work (specific cases)
#
# Improvement -> Use Govs open data on green areas, and look at elevation, to create a heuristic which will rank the routes.
# Instead of using the boundary, can iterate through each point

# %%
import a_star_random_with_arcs as AStarArcs
gen = AStarArcs.AStarArcs(10, 1)
gen.main()

# %%
coords = gen.generate_new()
folium.PolyLine(
    locations=coords,
    color="#00FF00",
    weight=5,
    tooltip="P2P-A*",
    opacity=0.5,
).add_to(m)
m
# Out:
# Distance Achieved: 9.025536000000002
# Time: 947.6572983264923
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b335dfecfc91930933fe1a1903cc3a4f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;style&gt;
#                 #scroll_zoom_toggler_cfd8577781777c19c0ee564abd1d01b0 {
#                     position:absolute;
#                     width:35px;
#                     bottom:10px;
#                     height:35px;
#                     left:10px;
#                     background-color:#fff;
#                     text-align:center;
#                     line-height:35px;
#                     vertical-align: middle;
#                     }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b335dfecfc91930933fe1a1903cc3a4f&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;scroll_zoom_toggler_cfd8577781777c19c0ee564abd1d01b0&quot;
#                  alt=&quot;scroll&quot;
#                  src=&quot;https://cdnjs.cloudflare.com/ajax/libs/ionicons/2.0.1/png/512/arrow-move.png&quot;
#                  style=&quot;z-index: 999999&quot;
#                  onclick=&quot;map_b335dfecfc91930933fe1a1903cc3a4f.toggleScroll()&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b335dfecfc91930933fe1a1903cc3a4f = L.map(
#                 &quot;map_b335dfecfc91930933fe1a1903cc3a4f&quot;,
#                 {
#                     center: [53.36486137451511, -1.8160056925378616],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6852579f47cbab321cf93eb169c64d73 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6852579f47cbab321cf93eb169c64d73.addTo(map_b335dfecfc91930933fe1a1903cc3a4f);
#
#
#             var tile_layer_09787a0d3ce4afc132ee39835a043f9d = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/outdoors-v12/tiles/{z}/{x}/{y}?access_token=pk.eyJ1IjoiZGFuLWxlZTc2IiwiYSI6ImNsaXJ4d3N3azE3M3Mza28xdnVmdGxwczcifQ.j0THIt59Yt7D6qG1WKXTPg&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             var tile_layer_a0613983687228117fd709bcc7324aa2 = L.tileLayer(
#                 &quot;https://api.os.uk/maps/raster/v1/zxy/Outdoor_3857/{z}/{x}/{y}.png?key=GGF16a7QH0WAQEkXEXqCwHwxLp0aoMAL&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             var tile_layer_cfa9bb6ddc90aa80dfecfea20d8a623a = L.tileLayer(
#                 &quot;https://a.tile.opentopomap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 OpenTopoMap&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cfa9bb6ddc90aa80dfecfea20d8a623a.addTo(map_b335dfecfc91930933fe1a1903cc3a4f);
#
#
#
#         function geo_json_f8ca0a846be8f291c823af19318fc345_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f8ca0a846be8f291c823af19318fc345 = L.geoJson(null, {
#                 onEachFeature: geo_json_f8ca0a846be8f291c823af19318fc345_onEachFeature,
#
#         });
#
#         function geo_json_f8ca0a846be8f291c823af19318fc345_add (data) {
#             geo_json_f8ca0a846be8f291c823af19318fc345
#                 .addData(data);
#         }
#             geo_json_f8ca0a846be8f291c823af19318fc345_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:EPSG::3857&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-1.818934671254997, 53.34142034903661], [-1.830488834572843, 53.34434684208792], [-1.830872034572843, 53.34463794208793], [-1.833789901239506, 53.34723817121106], [-1.834035301239507, 53.34749397121106], [-1.833301828788945, 53.38284170123951], [-1.818193709752948, 53.38252820475518], [-1.819188955991268, 53.38896018656338], [-1.818634455991268, 53.38904598656338], [-1.814784975947575, 53.38933998582319], [-1.814597175947575, 53.389339785823196], [-1.813656723186319, 53.389321088246135], [-1.806578823186319, 53.38904708824613], [-1.806644736085071, 53.387344442603535], [-1.792897423017739, 53.384369357989975], [-1.787086497854863, 53.38018881362697], [-1.782999934397857, 53.37840066687511], [-1.782463268651951, 53.367763771503206], [-1.782275895410569, 53.3665725153481], [-1.78084283238307, 53.365690140794406], [-1.778939227897911, 53.36723262852288], [-1.778087287798819, 53.

# %% [markdown]
# ## Genetic/Memetic Algorithm

# %% [markdown]
# 1. Generate population (100) which meets the criteria of distance. (Greedy search)
# 2. Complete generations (50)
#    1. Selection - using roulette. Primarily using SoftMax function. Which converts them into raw probabilities based on the population
#    2. Crossover - Pick a random point on both parents, and breed them
#    3. Mutation - 20% mutation rate, where it does random extensions within
#    4. Local Search(*) - *Picks a point, moves to a different neighbour, then extend route, avoiding current path*
# 3. Filter best route
# 4. Fitness - Based on distance from end node to target node, and length of route
#
# Time: 2 mins for best route, based on 100/100
# Pros: Can generate *some* decent routes. Still needs fine tuning. Can look at different selection.
# Cons: Some routes are horrendous.
#
# Experiment: Tried improving the crossover, by picking the route out of the two parents, with the closest distance to the target_node s the tail, got stuck
#
# Improvement -> Including a weighting/modifying the fitness. Population generation would mainly need improving, as if this is initially bad, then so are the rest of the routes.

# %%
import GA
coords = GA.generate_route()
folium.PolyLine(
    locations=coords,
    color="#FF0000",
    weight=5,
    tooltip="P2P-GA",
    opacity=0.5,
).add_to(m)
# Out:
# c:\Users\Dan-L\scoop\apps\miniconda3\24.7.1-0\Lib\site-packages\osmnx\graph.py:191: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   G = graph_from_bbox(
# Generating Population
# Heuristic: {18085463: 0.12418457343909556, 18085464: 0.12146208884923727, 18086229: 0.09675352235102351, 18086251: 0.03972698807511082, 18086252: 0.03710858340936763, 18086260: 0.02995709846630657, 18086264: 0.029361692154233728, 18086272: 0.03153781463735246, 18086290: 0.013455877532513967, 18086296: 0.005316877810332012, 18086300: 0.0015029491009347154, 18086301: 0.0033940740858147663, 18086303: 0.0035052984922823616, 18086305: 0.006496661238667148, 18086313: 0.009782848127718584, 18086329: 0.03642987432382861, 18086332: 0.03801259600408752, 18086338: 0.044239431034881024, 18086581: 0.12509995530039214, 18086599: 0.1230596185806706, 21232138: 0.04437249684770985, 21232141: 0.04407935540817165, 21232145: 0.04432242070758051, 21232150: 0.04207300246297878, 21232171: 0.030950135318765927, 21232197: 0.0532040055984501, 21232200: 0.05429899129081374, 21232202: 0.054651683664549394, 24940151: 0.05410184335972304, 26419947: 0.08604640421458551, 26420308: 0.0649625387204803, 26421391: 0.1266825495986724, 26421393: 0.1222647012900291, 26421396: 0.11797265629848333, 26421399: 0.10944982706158146, 26421401: 0.12657475279537408, 26421410: 0.035181274350994954, 26421432: 0.05501489232607928, 26421436: 0.07307592407386998, 26421444: 0.06599463454206016, 26421445: 0.0652803007030463, 26421447: 0.05787718782266652, 26421448: 0.06202379560910561, 26421473: 0.010861942590991968, 26421474: 0.012845509100070764, 36488265: 0.0013414619375890261, 36488270: 0.0011535594739757755, 36488273: 0.0018195467485061388, 36488308: 0.0032630007615696375, 36488336: 0.009403797992300188, 36488369: 0.019197284118332665, 36488374: 0.018606931113432416, 36488389: 0.023120388536960378, 36488403: 0.028538540482827116, 36488409: 0.030771977509739628, 36488419: 0.03198270719154253, 36488439: 0.03512667547064421, 36488441: 0.03469895428409909, 36488446: 0.034023937887463655, 36488459: 0.03424002136593955, 36488461: 0.030560934306725726, 36488465: 0.028274026568035977, 36488469: 0.026717727317270075, 36488483: 0.02470202934598688, 36488504: 0.0177918565138661, 36488511: 0.016604273076831922, 36488520: 0.013338321551455052, 36488521: 0.012936358846291223, 36488535: 0.007855127713792796, 36488546: 0.004233946887956776, 36488551: 0.0038584003317494154, 36488564: 0.0037008554213858974, 36488584: 0.0036922863702612344, 36566549: 0.02916783192233944, 36566593: 0.03277944338224759, 36566603: 0.03611460414582997, 89127587: 0.025241516947282855, 89127668: 0.025314019790029032, 89127679: 0.029197047152751412, 89127747: 0.020784216059307484, 89127767: 0.0013935914250625724, 244012960: 0.004035410383095455, 244013017: 0.010677946735679265, 244013031: 0.009366673192229794, 244013118: 0.04351225006420682, 245807047: 0.03243823520245865, 245808167: 0.0024830389485475165, 245916340: 0.02139724307685371, 245916350: 0.02162544941151495, 245916353: 0.020590828983793535, 245916354: 0.01956182260833492, 245916395: 0.007482556528350359, 245916398: 0.004414516169411539, 248810319: 0.04161088734862544, 248957551: 0.0956077353297324, 248957583: 0.09635031075653035, 248963020: 0.09247706089890456, 248963070: 0.09540474632558553, 248966302: 0.09386799746462787, 248966314: 0.09491490793257777, 253706512: 0.05565000250682812, 253706518: 0.05304428728195028, 253706521: 0.05267332701871409, 253706992: 0.05320711251035926, 253707000: 0.041945331262967726, 255174042: 0.05345749477725267, 255174044: 0.05471286159807389, 255174048: 0.04844509472062158, 255174049: 0.04562286182387071, 255174291: 0.03765237998241295, 255174453: 0.06429006324479718, 255174652: 0.003488265225011518, 256659084: 0.06925160701514714, 258604850: 0.112044188805175, 258604852: 0.11152119016267524, 258609547: 0.12752316885040846, 259851016: 0.0569946509814722, 259856724: 0.047774943174011576, 259856751: 0.0492782533624084, 259954284: 0.05453560520182958, 259958421: 0.0637838284658427, 259958436: 0.05754980684815501, 259958437: 0.05777557994109638, 259958445: 0.06018276736749366, 259960014: 0.05670065559585557, 262242234: 0.087333 ...
# Generation 1
# Generation 2
# Generation 3
# Generation 4
# Generation 5
# Generation 6
# Generation 7
# Generation 8
# Generation 9
# Generation 10
# Generation 11
# Generation 12
# Generation 13
# Generation 14
# Generation 15
# Generation 16
# Generation 17
# Generation 18
# Generation 19
# Generation 20
# Generation 21
# Generation 22
# Generation 23
# Generation 24
# Generation 25
# Generation 26
# Generation 27
# Generation 28
# Generation 29
# Generation 30
# Generation 31
# Generation 32
# Generation 33
# Generation 34
# Generation 35
# Generation 36
# Generation 37
# Generation 38
# Generation 39
# Generation 40
# Generation 41
# Generation 42
# Generation 43
# Generation 44
# Generation 45
# Generation 46
# Generation 47
# Generation 48
# Generation 49
# Generation 50
# Generation 51
# Generation 52
# Generation 53
# Generation 54
# Generation 55
# Generation 56
# Generation 57
# Generation 58
# Generation 59
# Generation 60
# Generation 61
# Generation 62
# Generation 63
# Generation 64
# Generation 65
# Generation 66
# Generation 67
# Generation 68
# Generation 69
# Generation 70
# Generation 71
# Generation 72
# Generation 73
# Generation 74
# Generation 75
# Generation 76
# Generation 77
# Generation 78
# Generation 79
# Generation 80
# Generation 81
# Generation 82
# Generation 83
# Generation 84
# Generation 85
# Generation 86
# Generation 87
# Generation 88
# Generation 89
# Generation 90
# Generation 91
# Generation 92
# Generation 93
# Generation 94
# Generation 95
# Generation 96
# Generation 97
# Generation 98
# Generation 99
# Generation 100
# Distance: 10015.279000000004

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_851b3542e24d091ea48922bb5097bef3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;style&gt;
#                 #scroll_zoom_toggler_5d97089717ee1409943b3a3db79628c7 {
#                     position:absolute;
#                     width:35px;
#                     bottom:10px;
#                     height:35px;
#                     left:10px;
#                     background-color:#fff;
#                     text-align:center;
#                     line-height:35px;
#                     vertical-align: middle;
#                     }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_851b3542e24d091ea48922bb5097bef3&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;scroll_zoom_toggler_5d97089717ee1409943b3a3db79628c7&quot;
#                  alt=&quot;scroll&quot;
#                  src=&quot;https://cdnjs.cloudflare.com/ajax/libs/ionicons/2.0.1/png/512/arrow-move.png&quot;
#                  style=&quot;z-index: 999999&quot;
#                  onclick=&quot;map_851b3542e24d091ea48922bb5097bef3.toggleScroll()&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_851b3542e24d091ea48922bb5097bef3 = L.map(
#                 &quot;map_851b3542e24d091ea48922bb5097bef3&quot;,
#                 {
#                     center: [53.36486137451511, -1.8160056925378616],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd621f1dd317b269b5e14ac0a86f9c86 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fd621f1dd317b269b5e14ac0a86f9c86.addTo(map_851b3542e24d091ea48922bb5097bef3);
#
#
#             var tile_layer_9456350455572697eba6cc7ab50b5950 = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/outdoors-v12/tiles/{z}/{x}/{y}?access_token=pk.eyJ1IjoiZGFuLWxlZTc2IiwiYSI6ImNsaXJ4d3N3azE3M3Mza28xdnVmdGxwczcifQ.j0THIt59Yt7D6qG1WKXTPg&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             var tile_layer_6f31f3873eabd1b2218415625bd6b297 = L.tileLayer(
#                 &quot;https://api.os.uk/maps/raster/v1/zxy/Outdoor_3857/{z}/{x}/{y}.png?key=GGF16a7QH0WAQEkXEXqCwHwxLp0aoMAL&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             var tile_layer_014cc78787002b01ada42f89a38317d9 = L.tileLayer(
#                 &quot;https://a.tile.opentopomap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 OpenTopoMap&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_014cc78787002b01ada42f89a38317d9.addTo(map_851b3542e24d091ea48922bb5097bef3);
#
#
#
#         function geo_json_566c3df5b854b3add3ab3f1bf10667ce_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_566c3df5b854b3add3ab3f1bf10667ce = L.geoJson(null, {
#                 onEachFeature: geo_json_566c3df5b854b3add3ab3f1bf10667ce_onEachFeature,
#
#         });
#
#         function geo_json_566c3df5b854b3add3ab3f1bf10667ce_add (data) {
#             geo_json_566c3df5b854b3add3ab3f1bf10667ce
#                 .addData(data);
#         }
#             geo_json_566c3df5b854b3add3ab3f1bf10667ce_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:EPSG::3857&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-1.818934671254997, 53.34142034903661], [-1.830488834572843, 53.34434684208792], [-1.830872034572843, 53.34463794208793], [-1.833789901239506, 53.34723817121106], [-1.834035301239507, 53.34749397121106], [-1.833301828788945, 53.38284170123951], [-1.818193709752948, 53.38252820475518], [-1.819188955991268, 53.38896018656338], [-1.818634455991268, 53.38904598656338], [-1.814784975947575, 53.38933998582319], [-1.814597175947575, 53.389339785823196], [-1.813656723186319, 53.389321088246135], [-1.806578823186319, 53.38904708824613], [-1.806644736085071, 53.387344442603535], [-1.792897423017739, 53.384369357989975], [-1.787086497854863, 53.38018881362697], [-1.782999934397857, 53.37840066687511], [-1.782463268651951, 53.367763771503206], [-1.782275895410569, 53.3665725153481], [-1.78084283238307, 53.365690140794406], [-1.778939227897911, 53.36723262852288], [-1.778087287798819, 53.

# %% [markdown]
# ## Iterative Deepening Depth First Search

# %% [markdown]
# Regular DFS, but with a cap on the amount of nodes.
#
# Time: (5653 Seconds from 1), (20 Seconds from 30) (10km)
#
# Pros: Consistent results, although contain weird decisions
# Cons: Can take time to build up to the 'first solution depth',  takes significant time if route is long (e.g 15km), as has to build up to the nodes
#
# Improvement: Look into some sort of cache (saves the route, then extends them at a later stage)?

# %%
import iddfs
coords = iddfs.generate_route(10)
folium.PolyLine(
    locations=coords,
    color="#0000FF",
    weight=5,
    tooltip="P2P - IDDFS",
    opacity=0.5,
).add_to(m)
m
# Out:
# c:\Users\Dan-L\scoop\apps\miniconda3\24.7.1-0\Lib\site-packages\osmnx\graph.py:191: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   G = graph_from_bbox(
# 6.279847621917725
# Amount of Nodes: 1452
# Amount of Edges: 3942
# Generating Route
# 0.0
# Depth: 1
# Depth: 2
# Depth: 3
# Depth: 4
# Depth: 5
# Depth: 6
# Depth: 7
# Depth: 8
# Depth: 9
# Depth: 10
# Depth: 11
# Depth: 12
# Depth: 13
# Depth: 14
# Depth: 15
# Depth: 16
# 0.30172276496887207
# Route Found
# Distance: 9.789465
# 31
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b025284af4d80d5faf3a2e99af691596 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;style&gt;
#                 #scroll_zoom_toggler_787b5705d2595dddf296be82c3954b95 {
#                     position:absolute;
#                     width:35px;
#                     bottom:10px;
#                     height:35px;
#                     left:10px;
#                     background-color:#fff;
#                     text-align:center;
#                     line-height:35px;
#                     vertical-align: middle;
#                     }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b025284af4d80d5faf3a2e99af691596&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;scroll_zoom_toggler_787b5705d2595dddf296be82c3954b95&quot;
#                  alt=&quot;scroll&quot;
#                  src=&quot;https://cdnjs.cloudflare.com/ajax/libs/ionicons/2.0.1/png/512/arrow-move.png&quot;
#                  style=&quot;z-index: 999999&quot;
#                  onclick=&quot;map_b025284af4d80d5faf3a2e99af691596.toggleScroll()&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b025284af4d80d5faf3a2e99af691596 = L.map(
#                 &quot;map_b025284af4d80d5faf3a2e99af691596&quot;,
#                 {
#                     center: [53.36486137451511, -1.8160056925378616],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e8e557c8280e30bdc1c45dc04afe68ad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e8e557c8280e30bdc1c45dc04afe68ad.addTo(map_b025284af4d80d5faf3a2e99af691596);
#
#
#             var tile_layer_e092e76503c018b22629473beb645796 = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/outdoors-v12/tiles/{z}/{x}/{y}?access_token=pk.eyJ1IjoiZGFuLWxlZTc2IiwiYSI6ImNsaXJ4d3N3azE3M3Mza28xdnVmdGxwczcifQ.j0THIt59Yt7D6qG1WKXTPg&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             var tile_layer_b11404f47f1a49f0744a237324177828 = L.tileLayer(
#                 &quot;https://api.os.uk/maps/raster/v1/zxy/Outdoor_3857/{z}/{x}/{y}.png?key=GGF16a7QH0WAQEkXEXqCwHwxLp0aoMAL&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             var tile_layer_4650a1e77a5278481b1501220d7b8991 = L.tileLayer(
#                 &quot;https://a.tile.opentopomap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 OpenTopoMap&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4650a1e77a5278481b1501220d7b8991.addTo(map_b025284af4d80d5faf3a2e99af691596);
#
#
#
#         function geo_json_8e84f0ec5b6f6e775f5926c048c54e68_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8e84f0ec5b6f6e775f5926c048c54e68 = L.geoJson(null, {
#                 onEachFeature: geo_json_8e84f0ec5b6f6e775f5926c048c54e68_onEachFeature,
#
#         });
#
#         function geo_json_8e84f0ec5b6f6e775f5926c048c54e68_add (data) {
#             geo_json_8e84f0ec5b6f6e775f5926c048c54e68
#                 .addData(data);
#         }
#             geo_json_8e84f0ec5b6f6e775f5926c048c54e68_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:EPSG::3857&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-1.818934671254997, 53.34142034903661], [-1.830488834572843, 53.34434684208792], [-1.830872034572843, 53.34463794208793], [-1.833789901239506, 53.34723817121106], [-1.834035301239507, 53.34749397121106], [-1.833301828788945, 53.38284170123951], [-1.818193709752948, 53.38252820475518], [-1.819188955991268, 53.38896018656338], [-1.818634455991268, 53.38904598656338], [-1.814784975947575, 53.38933998582319], [-1.814597175947575, 53.389339785823196], [-1.813656723186319, 53.389321088246135], [-1.806578823186319, 53.38904708824613], [-1.806644736085071, 53.387344442603535], [-1.792897423017739, 53.384369357989975], [-1.787086497854863, 53.38018881362697], [-1.782999934397857, 53.37840066687511], [-1.782463268651951, 53.367763771503206], [-1.782275895410569, 53.3665725153481], [-1.78084283238307, 53.365690140794406], [-1.778939227897911, 53.36723262852288], [-1.778087287798819, 53.

# %% [markdown]
# ## Depth First Search

# %% [markdown]
# Regular DFS
#
# Time: 30 seconds (10km)
#
# Pros: Quicker than IDDFS
# Con: Goes for greatest depth first, which may not always be optimal. Time increments

# %%
import dfs
dfs_gen = dfs.DFS_Generator(10,1)

# %%
coords = dfs_gen.generate_route()
folium.PolyLine(
    locations=coords,
    color="#FF00FF",
    weight=5,
    tooltip="P2P - DFS",
    opacity=0.5,
).add_to(m)
m
# Out:
# 0.10227084159851074
# Route Found
# Distance: 9.309891000000002
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_79c0337aef11cf27d7ec78866beb8610 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;style&gt;
#                 #scroll_zoom_toggler_e91e5f15f40f4fe1fd95d1d87b34f503 {
#                     position:absolute;
#                     width:35px;
#                     bottom:10px;
#                     height:35px;
#                     left:10px;
#                     background-color:#fff;
#                     text-align:center;
#                     line-height:35px;
#                     vertical-align: middle;
#                     }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_79c0337aef11cf27d7ec78866beb8610&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;scroll_zoom_toggler_e91e5f15f40f4fe1fd95d1d87b34f503&quot;
#                  alt=&quot;scroll&quot;
#                  src=&quot;https://cdnjs.cloudflare.com/ajax/libs/ionicons/2.0.1/png/512/arrow-move.png&quot;
#                  style=&quot;z-index: 999999&quot;
#                  onclick=&quot;map_79c0337aef11cf27d7ec78866beb8610.toggleScroll()&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_79c0337aef11cf27d7ec78866beb8610 = L.map(
#                 &quot;map_79c0337aef11cf27d7ec78866beb8610&quot;,
#                 {
#                     center: [53.36486137451511, -1.8160056925378616],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b5f4429722231d7f31d245fdcec1579 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6b5f4429722231d7f31d245fdcec1579.addTo(map_79c0337aef11cf27d7ec78866beb8610);
#
#
#             var tile_layer_0ece9db02b7c89fba7bffb96bdda00ac = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/outdoors-v12/tiles/{z}/{x}/{y}?access_token=pk.eyJ1IjoiZGFuLWxlZTc2IiwiYSI6ImNsaXJ4d3N3azE3M3Mza28xdnVmdGxwczcifQ.j0THIt59Yt7D6qG1WKXTPg&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             var tile_layer_c41278511ed6fa4785921eb05052bfe8 = L.tileLayer(
#                 &quot;https://api.os.uk/maps/raster/v1/zxy/Outdoor_3857/{z}/{x}/{y}.png?key=GGF16a7QH0WAQEkXEXqCwHwxLp0aoMAL&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             var tile_layer_89b690b24d44c9db740f34128137796b = L.tileLayer(
#                 &quot;https://a.tile.opentopomap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 OpenTopoMap&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_89b690b24d44c9db740f34128137796b.addTo(map_79c0337aef11cf27d7ec78866beb8610);
#
#
#
#         function geo_json_0b1324f8ac608b333f510ea24af01d5a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_0b1324f8ac608b333f510ea24af01d5a = L.geoJson(null, {
#                 onEachFeature: geo_json_0b1324f8ac608b333f510ea24af01d5a_onEachFeature,
#
#         });
#
#         function geo_json_0b1324f8ac608b333f510ea24af01d5a_add (data) {
#             geo_json_0b1324f8ac608b333f510ea24af01d5a
#                 .addData(data);
#         }
#             geo_json_0b1324f8ac608b333f510ea24af01d5a_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:EPSG::3857&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-1.818934671254997, 53.34142034903661], [-1.830488834572843, 53.34434684208792], [-1.830872034572843, 53.34463794208793], [-1.833789901239506, 53.34723817121106], [-1.834035301239507, 53.34749397121106], [-1.833301828788945, 53.38284170123951], [-1.818193709752948, 53.38252820475518], [-1.819188955991268, 53.38896018656338], [-1.818634455991268, 53.38904598656338], [-1.814784975947575, 53.38933998582319], [-1.814597175947575, 53.389339785823196], [-1.813656723186319, 53.389321088246135], [-1.806578823186319, 53.38904708824613], [-1.806644736085071, 53.387344442603535], [-1.792897423017739, 53.384369357989975], [-1.787086497854863, 53.38018881362697], [-1.782999934397857, 53.37840066687511], [-1.782463268651951, 53.367763771503206], [-1.782275895410569, 53.3665725153481], [-1.78084283238307, 53.365690140794406], [-1.778939227897911, 53.36723262852288], [-1.778087287798819, 53.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36240bbf82bbe2bf09bba6057c29461b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;style&gt;
#                 #scroll_zoom_toggler_2c74e2dc713152790ab4652c4b889602 {
#                     position:absolute;
#                     width:35px;
#                     bottom:10px;
#                     height:35px;
#                     left:10px;
#                     background-color:#fff;
#                     text-align:center;
#                     line-height:35px;
#                     vertical-align: middle;
#                     }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36240bbf82bbe2bf09bba6057c29461b&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;scroll_zoom_toggler_2c74e2dc713152790ab4652c4b889602&quot;
#                  alt=&quot;scroll&quot;
#                  src=&quot;https://cdnjs.cloudflare.com/ajax/libs/ionicons/2.0.1/png/512/arrow-move.png&quot;
#                  style=&quot;z-index: 999999&quot;
#                  onclick=&quot;map_36240bbf82bbe2bf09bba6057c29461b.toggleScroll()&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36240bbf82bbe2bf09bba6057c29461b = L.map(
#                 &quot;map_36240bbf82bbe2bf09bba6057c29461b&quot;,
#                 {
#                     center: [53.36486137451511, -1.8160056925378616],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_058d4204faa02d31b97abce69467f32f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_058d4204faa02d31b97abce69467f32f.addTo(map_36240bbf82bbe2bf09bba6057c29461b);
#
#
#             var tile_layer_c732eaceab7c83ee9275158b669aecdb = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/outdoors-v12/tiles/{z}/{x}/{y}?access_token=pk.eyJ1IjoiZGFuLWxlZTc2IiwiYSI6ImNsaXJ4d3N3azE3M3Mza28xdnVmdGxwczcifQ.j0THIt59Yt7D6qG1WKXTPg&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             var tile_layer_2dbc5c171ecd839854965b60dc104b97 = L.tileLayer(
#                 &quot;https://api.os.uk/maps/raster/v1/zxy/Outdoor_3857/{z}/{x}/{y}.png?key=GGF16a7QH0WAQEkXEXqCwHwxLp0aoMAL&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             var tile_layer_07551f4070833a7e3d8f3bea614a35e3 = L.tileLayer(
#                 &quot;https://a.tile.opentopomap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 OpenTopoMap&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_07551f4070833a7e3d8f3bea614a35e3.addTo(map_36240bbf82bbe2bf09bba6057c29461b);
#
#
#
#         function geo_json_f72a8825e0c2fc23b65eaa01e8b6d5e9_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f72a8825e0c2fc23b65eaa01e8b6d5e9 = L.geoJson(null, {
#                 onEachFeature: geo_json_f72a8825e0c2fc23b65eaa01e8b6d5e9_onEachFeature,
#
#         });
#
#         function geo_json_f72a8825e0c2fc23b65eaa01e8b6d5e9_add (data) {
#             geo_json_f72a8825e0c2fc23b65eaa01e8b6d5e9
#                 .addData(data);
#         }
#             geo_json_f72a8825e0c2fc23b65eaa01e8b6d5e9_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:EPSG::3857&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-1.818934671254997, 53.34142034903661], [-1.830488834572843, 53.34434684208792], [-1.830872034572843, 53.34463794208793], [-1.833789901239506, 53.34723817121106], [-1.834035301239507, 53.34749397121106], [-1.833301828788945, 53.38284170123951], [-1.818193709752948, 53.38252820475518], [-1.819188955991268, 53.38896018656338], [-1.818634455991268, 53.38904598656338], [-1.814784975947575, 53.38933998582319], [-1.814597175947575, 53.389339785823196], [-1.813656723186319, 53.389321088246135], [-1.806578823186319, 53.38904708824613], [-1.806644736085071, 53.387344442603535], [-1.792897423017739, 53.384369357989975], [-1.787086497854863, 53.38018881362697], [-1.782999934397857, 53.37840066687511], [-1.782463268651951, 53.367763771503206], [-1.782275895410569, 53.3665725153481], [-1.78084283238307, 53.365690140794406], [-1.778939227897911, 53.36723262852288], [-1.778087287798819, 53.
