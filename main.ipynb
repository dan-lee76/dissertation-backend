# %% [markdown]
# # Types of routing
# ## Map Initialisation

# %%
import folium
import folium.plugins as plugins

# Center coordinates for the map
center_coordinates = [53.36486137451511, -1.8160056925378616]  # Example: Central London

tiles = "https://api.os.uk/maps/raster/v1/zxy/Leisure_27700/{z}/{x}/{y}.png?key=GGF16a7QH0WAQEkXEXqCwHwxLp0aoMAL"
tiles_mapbox = "https://api.mapbox.com/styles/v1/mapbox/outdoors-v12/tiles/{z}/{x}/{y}?access_token=pk.eyJ1IjoiZGFuLWxlZTc2IiwiYSI6ImNsaXJ4d3N3azE3M3Mza28xdnVmdGxwczcifQ.j0THIt59Yt7D6qG1WKXTPg"
tiles_mapbox2 = "https://api.mapbox.com/v4/dan-lee76.Outdoors/{z}/{x}/{y}.png?access_token=pk.eyJ1IjoiZGFuLWxlZTc2IiwiYSI6ImNsaXJ4d3N3azE3M3Mza28xdnVmdGxwczcifQ.j0THIt59Yt7D6qG1WKXTPg"
tile_backup = "opentopomap"

# Initialize the map using OS Maps as the default tiles
m = folium.Map(location=center_coordinates, zoom_start=13, max_zoom=20, min_zoom=0, attr="© Ordnance Survey")

folium.TileLayer(
    name="Mapbox Outdoors",
    tiles="https://api.mapbox.com/styles/v1/mapbox/outdoors-v12/tiles/{z}/{x}/{y}?access_token=pk.eyJ1IjoiZGFuLWxlZTc2IiwiYSI6ImNsaXJ4d3N3azE3M3Mza28xdnVmdGxwczcifQ.j0THIt59Yt7D6qG1WKXTPg",
    attr="© Mapbox",
    overlay=False,
    control=True,
    show=False,
).add_to(m)

folium.TileLayer(
    name="OS Maps Road",
    tiles="https://api.os.uk/maps/raster/v1/zxy/Outdoor_3857/{z}/{x}/{y}.png?key=GGF16a7QH0WAQEkXEXqCwHwxLp0aoMAL",
    attr="© Ordnance Survey",
    overlay=False,
    control=True,
    show=False,
).add_to(m)

# folium.TileLayer(
#     name="OS Maps Lesiure",
#     tiles="https://api.os.uk/maps/raster/v1/zxy/Leisure_27700/{z}/{x}/{y}.png?key=GGF16a7QH0WAQEkXEXqCwHwxLp0aoMAL",
#     attr="© Ordnance Survey",
#     overlay=False,
#     control=True,
#     crs="EPSG27700",
# ).add_to(m)

folium.TileLayer(
    name="OpenTopoMap",
    tiles="https://a.tile.opentopomap.org/{z}/{x}/{y}.png",
    attr="© OpenTopoMap",
    overlay=False,
    control=True,
    show=True,
).add_to(m)

folium.GeoJson(
    data="route_buffer.geojson",
    name="GeoJSON",
    overlay=True,
    control=True,
    show=False,
).add_to(m)

folium.plugins.ScrollZoomToggler().add_to(m)

folium.LayerControl().add_to(m)

# %%
import GA
coords = GA.funny()
# Out:
# c:\Users\Dan-L\scoop\apps\miniconda3\24.7.1-0\Lib\site-packages\osmnx\graph.py:191: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   G = graph_from_bbox(
# Start node information: {262360538: {0: {'osmid': 439057297, 'highway': 'unclassified', 'oneway': False, 'reversed': True, 'length': 34.624}}, 262360561: {0: {'osmid': 42440870, 'lanes': '2', 'name': 'Marys Lane', 'highway': 'residential', 'maxspeed': '30 mph', 'oneway': False, 'reversed': False, 'length': 32.775, 'geometry': <LINESTRING (-1.82 53.4, -1.82 53.4, -1.82 53.4)>}}, 262360495: {0: {'osmid': [62362281, 62362282, 62362301], 'name': 'Marys Lane', 'highway': 'residential', 'maxspeed': '20 mph', 'oneway': False, 'reversed': [False, True], 'length': 47.39, 'geometry': <LINESTRING (-1.82 53.4, -1.82 53.4, -1.82 53.4, -1.82 53.4, -1.82 53.4, -1....>}}}
# Running memetic algorithm...
# Evolving...
# Generating Population
# Generation 1
# Population Size: 100
# Generation 2
# Population Size: 100
# Generation 3
# Population Size: 100
# Generation 4
# Population Size: 100
# Generation 5
# Population Size: 100
# Generation 6
# Population Size: 100
# Generation 7
# Population Size: 100
# Generation 8
# Population Size: 100
# Generation 9
# Population Size: 100
# Generation 10
# Population Size: 100
# Generation 11
# Population Size: 100
# Generation 12
# Population Size: 100
# Generation 13
# Population Size: 100
# Generation 14
# Population Size: 100
# Generation 15
# Population Size: 100
# Generation 16
# Population Size: 100
# Generation 17
# Population Size: 100
# Generation 18
# Population Size: 100
# Generation 19
# Population Size: 100
# Generation 20
# Population Size: 100
# Generation 21
# Population Size: 100
# Generation 22
# Population Size: 100
# Generation 23
# Population Size: 100
# Generation 24
# Population Size: 100
# Generation 25
# Population Size: 100
# Generation 26
# Population Size: 100
# Generation 27
# Population Size: 100
# Generation 28
# Population Size: 100
# Generation 29
# Population Size: 100
# Generation 30
# Population Size: 100
# Generation 31
# Population Size: 100
# Generation 32
# Population Size: 100
# Generation 33
# Population Size: 100
# Generation 34
# Population Size: 100
# Generation 35
# Population Size: 100
# Generation 36
# Population Size: 100
# Generation 37
# Population Size: 100
# Generation 38
# Population Size: 100
# Generation 39
# Population Size: 100
# Generation 40
# Population Size: 100
# Generation 41
# Population Size: 100
# Generation 42
# Population Size: 100
# Generation 43
# Population Size: 100
# Generation 44
# Population Size: 100
# Generation 45
# Population Size: 100
# Generation 46
# Population Size: 100
# Generation 47
# Population Size: 100
# Generation 48
# Population Size: 100
# Generation 49
# Population Size: 100
# Generation 50
# Population Size: 100
# Generation 51
# Population Size: 100
# Generation 52
# Population Size: 100
# Generation 53
# Population Size: 100
# Generation 54
# Population Size: 100
# Generation 55
# Population Size: 100
# Generation 56
# Population Size: 100
# Generation 57
# Population Size: 100
# Generation 58
# Population Size: 100
# Generation 59
# Population Size: 100
# Generation 60
# Population Size: 100
# Generation 61
# Population Size: 100
# Generation 62
# Population Size: 100
# Generation 63
# Population Size: 100
# Generation 64
# Population Size: 100
# Generation 65
# Population Size: 100
# Generation 66
# Population Size: 100
# Generation 67
# Population Size: 100
# Generation 68
# Population Size: 100
# Generation 69
# Population Size: 100
# Generation 70
# Population Size: 100
# Generation 71
# Population Size: 100
# Generation 72
# Population Size: 100
# Generation 73
# Population Size: 100
# Generation 74
# Population Size: 100
# Generation 75
# Population Size: 100
# Generation 76
# Population Size: 100
# Generation 77
# Population Size: 100
# Generation 78
# Population Size: 100
# Generation 79
# Population Size: 100
# Generation 80
# Population Size: 100
# Generation 81
# Population Size: 100
# Generation 82
# Population Size: 100
# Generation 83
# Population Size: 100
# Generation 84
# Population Size: 100
# Generation 85
# Population Size: 100
# Generation 86
# Population Size: 100
# Generation 87
# Population Size: 100
# Generation 88
# Population Size: 100
# Generation 89
# Population Size: 100
# Generation 90
# Population Size: 100
# Generation 91
# Population Size: 100
# Generation 92
# Population Size: 100
# Generation 93
# Population Size: 100
# Generation 94
# Population Size: 100
# Generation 95
# Population Size: 100
# Generation 96
# Population Size: 100
# Generation 97
# Population Size: 100
# Generation 98
# Population Size: 100
# Generation 99
# Population Size: 100
# Generation 100
# Population Size: 100
# [(53.3648011, -1.8159947), (53.3645453, -1.8157493), (53.3648011, -1.8159947), (53.3645453, -1.8157493), (53.3642542, -1.8153661), (53.3645453, -1.8157493), (53.3642542, -1.8153661), (53.36434, -1.8148116), (53.3643398, -1.8146238), (53.3640658, -1.8075459), (53.3640755, -1.8074974), (53.3638855, -1.8074162), (53.3578382, -1.7988276), (53.3573651, -1.7972903), (53.3573259, -1.797223), (53.35558, -1.8001935), (53.3544616, -1.8009237), (53.353761, -1.8013233), (53.3544616, -1.8009237), (53.353761, -1.8013233), (53.3535887, -1.8013492), (53.3526892, -1.8015151), (53.3519272, -1.8025132), (53.3518252, -1.8025726), (53.3510559, -1.8018004), (53.3503112, -1.7998742), (53.3480857, -1.7996377), (53.3477477, -1.7991849), (53.3442654, -1.7956348), (53.3427014, -1.79231), (53.3423043, -1.7921621), (53.3420323, -1.7917561), (53.3426902, -1.790623), (53.3420323, -1.7917561), (53.3420849, -1.7917189), (53.3427432, -1.7915202), (53.3427014, -1.79231), (53.3442654, -1.7956348), (53.3477477, -1.7991849), (53.3480857, -1.7996377), (53.3503112, -1.7998742), (53.3502289, -1.8026814), (53.3481086, -1.8039286), (53.3544017, -1.8038778), (53.3566933, -1.8017863), (53.3556801, -1.8045662), (53.3521074, -1.8081184), (53.3519119, -1.8083361), (53.3490183, -1.8102269), (53.3486889, -1.8111845), (53.3476654, -1.8135469), (53.3486796, -1.8130377), (53.3568649, -1.813024), (53.3581504, -1.815108), (53.3636965, -1.8163153)]

# %%
folium.PolyLine(
    locations=coords,
    color="#FF0000",
    weight=5,
    tooltip="GA",
    opacity=0.5,
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3606c498cc94ee34c1eefac2dff157db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;style&gt;
#                 #scroll_zoom_toggler_6b91401d8f0a29c2ab801d7da6da1636 {
#                     position:absolute;
#                     width:35px;
#                     bottom:10px;
#                     height:35px;
#                     left:10px;
#                     background-color:#fff;
#                     text-align:center;
#                     line-height:35px;
#                     vertical-align: middle;
#                     }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3606c498cc94ee34c1eefac2dff157db&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;scroll_zoom_toggler_6b91401d8f0a29c2ab801d7da6da1636&quot;
#                  alt=&quot;scroll&quot;
#                  src=&quot;https://cdnjs.cloudflare.com/ajax/libs/ionicons/2.0.1/png/512/arrow-move.png&quot;
#                  style=&quot;z-index: 999999&quot;
#                  onclick=&quot;map_3606c498cc94ee34c1eefac2dff157db.toggleScroll()&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3606c498cc94ee34c1eefac2dff157db = L.map(
#                 &quot;map_3606c498cc94ee34c1eefac2dff157db&quot;,
#                 {
#                     center: [53.36486137451511, -1.8160056925378616],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_781b1ef94f32caee6efa85df36fd08a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_781b1ef94f32caee6efa85df36fd08a4.addTo(map_3606c498cc94ee34c1eefac2dff157db);
#
#
#             var tile_layer_7f88f61d88bdc1e9bafd24429741bcb1 = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/outdoors-v12/tiles/{z}/{x}/{y}?access_token=pk.eyJ1IjoiZGFuLWxlZTc2IiwiYSI6ImNsaXJ4d3N3azE3M3Mza28xdnVmdGxwczcifQ.j0THIt59Yt7D6qG1WKXTPg&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             var tile_layer_220025d513addf6f35dc29f3f5026b40 = L.tileLayer(
#                 &quot;https://api.os.uk/maps/raster/v1/zxy/Outdoor_3857/{z}/{x}/{y}.png?key=GGF16a7QH0WAQEkXEXqCwHwxLp0aoMAL&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             var tile_layer_b37cadebc96ff08620f800b6812cbff6 = L.tileLayer(
#                 &quot;https://a.tile.opentopomap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 OpenTopoMap&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b37cadebc96ff08620f800b6812cbff6.addTo(map_3606c498cc94ee34c1eefac2dff157db);
#
#
#
#         function geo_json_bc867e8035f464b65336339760416fdb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_bc867e8035f464b65336339760416fdb = L.geoJson(null, {
#                 onEachFeature: geo_json_bc867e8035f464b65336339760416fdb_onEachFeature,
#
#         });
#
#         function geo_json_bc867e8035f464b65336339760416fdb_add (data) {
#             geo_json_bc867e8035f464b65336339760416fdb
#                 .addData(data);
#         }
#             geo_json_bc867e8035f464b65336339760416fdb_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-1.818934671254997, 53.34142034903661], [-1.830488834572843, 53.34434684208792], [-1.830872034572843, 53.34463794208793], [-1.833789901239506, 53.34723817121106], [-1.834035301239507, 53.34749397121106], [-1.833301828788945, 53.38284170123951], [-1.818193709752948, 53.38252820475518], [-1.819188955991268, 53.38896018656338], [-1.818634455991268, 53.38904598656338], [-1.814784975947575, 53.38933998582319], [-1.814597175947575, 53.389339785823196], [-1.813656723186319, 53.389321088246135], [-1.806578823186319, 53.38904708824613], [-1.806644736085071, 53.387344442603535], [-1.792897423017739, 53.384369357989975], [-1.787086497854863, 53.38018881362697], [-1.782999934397857, 53.37840066687511], [-1.782463268651951, 53.367763771503206], [-1.782275895410569, 53.3665725153481], [-1.78084283238307, 53.365690140794406], [-1.778939227897911, 53.36723262852288], [-1.778087287798819,

# %% [markdown]
# # Point-to-point routing
# ## A-Star with arcs

# %%
from a_star_random_with_arcs import a_star_assisted, generate_route
coords = generate_route(10)
folium.PolyLine(
    locations=coords,
    color="#00FF00",
    weight=5,
    tooltip="P2P-A*",
    opacity=0.5,
).add_to(m)
m
# Out:
# POINT (-1.818934671254997 53.34142034903661)
# POINT (-1.830488834572843 53.34434684208792)
# POINT (-1.830872034572843 53.34463794208793)
# POINT (-1.833789901239506 53.34723817121106)
# Distance: 8.949251999999998
# POINT (-1.834035301239507 53.34749397121106)
# Distance: 9.536179999999998
# Distance Achieved: 9.536179999999998
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3606c498cc94ee34c1eefac2dff157db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;style&gt;
#                 #scroll_zoom_toggler_6b91401d8f0a29c2ab801d7da6da1636 {
#                     position:absolute;
#                     width:35px;
#                     bottom:10px;
#                     height:35px;
#                     left:10px;
#                     background-color:#fff;
#                     text-align:center;
#                     line-height:35px;
#                     vertical-align: middle;
#                     }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3606c498cc94ee34c1eefac2dff157db&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;scroll_zoom_toggler_6b91401d8f0a29c2ab801d7da6da1636&quot;
#                  alt=&quot;scroll&quot;
#                  src=&quot;https://cdnjs.cloudflare.com/ajax/libs/ionicons/2.0.1/png/512/arrow-move.png&quot;
#                  style=&quot;z-index: 999999&quot;
#                  onclick=&quot;map_3606c498cc94ee34c1eefac2dff157db.toggleScroll()&quot;&gt;
#             &lt;/img&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3606c498cc94ee34c1eefac2dff157db = L.map(
#                 &quot;map_3606c498cc94ee34c1eefac2dff157db&quot;,
#                 {
#                     center: [53.36486137451511, -1.8160056925378616],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_781b1ef94f32caee6efa85df36fd08a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_781b1ef94f32caee6efa85df36fd08a4.addTo(map_3606c498cc94ee34c1eefac2dff157db);
#
#
#             var tile_layer_7f88f61d88bdc1e9bafd24429741bcb1 = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/outdoors-v12/tiles/{z}/{x}/{y}?access_token=pk.eyJ1IjoiZGFuLWxlZTc2IiwiYSI6ImNsaXJ4d3N3azE3M3Mza28xdnVmdGxwczcifQ.j0THIt59Yt7D6qG1WKXTPg&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             var tile_layer_220025d513addf6f35dc29f3f5026b40 = L.tileLayer(
#                 &quot;https://api.os.uk/maps/raster/v1/zxy/Outdoor_3857/{z}/{x}/{y}.png?key=GGF16a7QH0WAQEkXEXqCwHwxLp0aoMAL&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             var tile_layer_b37cadebc96ff08620f800b6812cbff6 = L.tileLayer(
#                 &quot;https://a.tile.opentopomap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 OpenTopoMap&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b37cadebc96ff08620f800b6812cbff6.addTo(map_3606c498cc94ee34c1eefac2dff157db);
#
#
#
#         function geo_json_bc867e8035f464b65336339760416fdb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_bc867e8035f464b65336339760416fdb = L.geoJson(null, {
#                 onEachFeature: geo_json_bc867e8035f464b65336339760416fdb_onEachFeature,
#
#         });
#
#         function geo_json_bc867e8035f464b65336339760416fdb_add (data) {
#             geo_json_bc867e8035f464b65336339760416fdb
#                 .addData(data);
#         }
#             geo_json_bc867e8035f464b65336339760416fdb_add({&quot;crs&quot;: {&quot;properties&quot;: {&quot;name&quot;: &quot;urn:ogc:def:crs:OGC:1.3:CRS84&quot;}, &quot;type&quot;: &quot;name&quot;}, &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-1.818934671254997, 53.34142034903661], [-1.830488834572843, 53.34434684208792], [-1.830872034572843, 53.34463794208793], [-1.833789901239506, 53.34723817121106], [-1.834035301239507, 53.34749397121106], [-1.833301828788945, 53.38284170123951], [-1.818193709752948, 53.38252820475518], [-1.819188955991268, 53.38896018656338], [-1.818634455991268, 53.38904598656338], [-1.814784975947575, 53.38933998582319], [-1.814597175947575, 53.389339785823196], [-1.813656723186319, 53.389321088246135], [-1.806578823186319, 53.38904708824613], [-1.806644736085071, 53.387344442603535], [-1.792897423017739, 53.384369357989975], [-1.787086497854863, 53.38018881362697], [-1.782999934397857, 53.37840066687511], [-1.782463268651951, 53.367763771503206], [-1.782275895410569, 53.3665725153481], [-1.78084283238307, 53.365690140794406], [-1.778939227897911, 53.36723262852288], [-1.778087287798819,

# %%
import geopandas
import json
gdf = "route_buffer.geojson"
folium.GeoJson(
    gdf,
).add_to(m)


with open('route_buffer.geojson', 'r') as file:
    data = json.load(file)
print(data)
folium.GeoJson(
    data,
).add_to(m)
m
# Out:
# {'type': 'FeatureCollection', 'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'}}, 'features': [{'type': 'Feature', 'properties': {}, 'geometry': {'type': 'Polygon', 'coordinates': [[[-1.818934671254997, 53.34142034903661], [-1.830488834572843, 53.34434684208792], [-1.830872034572843, 53.34463794208793], [-1.833789901239506, 53.34723817121106], [-1.834035301239507, 53.34749397121106], [-1.833301828788945, 53.38284170123951], [-1.818193709752948, 53.38252820475518], [-1.819188955991268, 53.38896018656338], [-1.818634455991268, 53.38904598656338], [-1.814784975947575, 53.38933998582319], [-1.814597175947575, 53.389339785823196], [-1.813656723186319, 53.389321088246135], [-1.806578823186319, 53.38904708824613], [-1.806644736085071, 53.387344442603535], [-1.792897423017739, 53.384369357989975], [-1.787086497854863, 53.38018881362697], [-1.782999934397857, 53.37840066687511], [-1.782463268651951, 53.367763771503206], [-1.782275895410569, 53.3665725153481], [-1.78084283238307, 53.365690140794406], [-1.778939227897911, 53.36723262852288], [-1.778087287798819, 53.36926248774308], [-1.776998238358693, 53.36880540930202], [-1.77491303850582, 53.37049504347212], [-1.771763760454178, 53.36660847782013], [-1.770235087798819, 53.36596688774308], [-1.77057931034748, 53.36514673229442], [-1.76822823850582, 53.36224524347212], [-1.76744291390583, 53.35743945896177], [-1.754382610650399, 53.34939788714316], [-1.754265810650399, 53.34890678714316], [-1.774702896523729, 53.31842593118305], [-1.775748096523729, 53.318261531183055], [-1.775804412879183, 53.318252738932564], [-1.776081912879183, 53.31820973893256], [-1.789546300116311, 53.31984666107028], [-1.797406000116311, 53.323129861070285], [-1.801400696669694, 53.33536565265369], [-1.801992717026591, 53.334885939487094], [-1.802998790028463, 53.33257443642313], [-1.80420009876584, 53.33309730152612], [-1.80707576149418, 53.330767156527884], [-1.811938243212152, 53.33676800945945], [-1.813220458740321, 53.33739692760122], [-1.818934671254997, 53.34142034903661]]]}}]}
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2be4d472d0c3b002fab86626e58f917 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2be4d472d0c3b002fab86626e58f917&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2be4d472d0c3b002fab86626e58f917 = L.map(
#                 &quot;map_b2be4d472d0c3b002fab86626e58f917&quot;,
#                 {
#                     center: [53.36486137451511, -1.8160056925378616],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00492a89143bc809e2c74e74345bb9aa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_00492a89143bc809e2c74e74345bb9aa.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             var tile_layer_496fccb7eb11e9ab995d57a8e594dd88 = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/outdoors-v12/tiles/{z}/{x}/{y}?access_token=pk.eyJ1IjoiZGFuLWxlZTc2IiwiYSI6ImNsaXJ4d3N3azE3M3Mza28xdnVmdGxwczcifQ.j0THIt59Yt7D6qG1WKXTPg&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_496fccb7eb11e9ab995d57a8e594dd88.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             var tile_layer_0008958ef016c8a8414353b502f4dd5c = L.tileLayer(
#                 &quot;https://api.os.uk/maps/raster/v1/zxy/Road_3857/{z}/{x}/{y}.png?key=GGF16a7QH0WAQEkXEXqCwHwxLp0aoMAL&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0008958ef016c8a8414353b502f4dd5c.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             var tile_layer_3d79495ed85d750fa8744fc18df2e30e = L.tileLayer(
#                 &quot;https://a.tile.opentopomap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 OpenTopoMap&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3d79495ed85d750fa8744fc18df2e30e.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             var layer_control_8569fecc05eb0f02bf1d49ba8f7847b4_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_00492a89143bc809e2c74e74345bb9aa,
#                     &quot;Mapbox Outdoors&quot; : tile_layer_496fccb7eb11e9ab995d57a8e594dd88,
#                     &quot;OS Maps&quot; : tile_layer_0008958ef016c8a8414353b502f4dd5c,
#                     &quot;OpenTopoMap&quot; : tile_layer_3d79495ed85d750fa8744fc18df2e30e,
#                 },
#                 overlays :  {
#                     &quot;macro_element_da0bf92d914e863f3b8c90a613e8eab0&quot; : geo_json_da0bf92d914e863f3b8c90a613e8eab0,
#                     &quot;macro_element_7d682379f4d204034060afcac78188c0&quot; : geo_json_7d682379f4d204034060afcac78188c0,
#                 },
#             };
#             let layer_control_8569fecc05eb0f02bf1d49ba8f7847b4 = L.control.layers(
#                 layer_control_8569fecc05eb0f02bf1d49ba8f7847b4_layers.base_layers,
#                 layer_control_8569fecc05eb0f02bf1d49ba8f7847b4_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#
#             tile_layer_00492a89143bc809e2c74e74345bb9aa.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             tile_layer_496fccb7eb11e9ab995d57a8e594dd88.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             tile_layer_0008958ef016c8a8414353b502f4dd5c.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             tile_layer_3d79495ed85d750fa8744fc18df2e30e.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             tile_layer_00492a89143bc809e2c74e74345bb9aa.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             tile_layer_496fccb7eb11e9ab995d57a8e594dd88.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             tile_layer_0008958ef016c8a8414353b502f4dd5c.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             tile_layer_3d79495ed85d750fa8744fc18df2e30e.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#
#         function geo_json_da0bf92d914e863f3b8c90a613e8eab0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_da0bf92d914e863f3b8c

# %% [markdown]
# ## Iterative Deepening Depth first search

# %%
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2be4d472d0c3b002fab86626e58f917 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2be4d472d0c3b002fab86626e58f917&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2be4d472d0c3b002fab86626e58f917 = L.map(
#                 &quot;map_b2be4d472d0c3b002fab86626e58f917&quot;,
#                 {
#                     center: [53.36486137451511, -1.8160056925378616],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00492a89143bc809e2c74e74345bb9aa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_00492a89143bc809e2c74e74345bb9aa.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             var tile_layer_496fccb7eb11e9ab995d57a8e594dd88 = L.tileLayer(
#                 &quot;https://api.mapbox.com/styles/v1/mapbox/outdoors-v12/tiles/{z}/{x}/{y}?access_token=pk.eyJ1IjoiZGFuLWxlZTc2IiwiYSI6ImNsaXJ4d3N3azE3M3Mza28xdnVmdGxwczcifQ.j0THIt59Yt7D6qG1WKXTPg&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Mapbox&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_496fccb7eb11e9ab995d57a8e594dd88.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             var tile_layer_0008958ef016c8a8414353b502f4dd5c = L.tileLayer(
#                 &quot;https://api.os.uk/maps/raster/v1/zxy/Road_3857/{z}/{x}/{y}.png?key=GGF16a7QH0WAQEkXEXqCwHwxLp0aoMAL&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 Ordnance Survey&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0008958ef016c8a8414353b502f4dd5c.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             var tile_layer_3d79495ed85d750fa8744fc18df2e30e = L.tileLayer(
#                 &quot;https://a.tile.opentopomap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u00a9 OpenTopoMap&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3d79495ed85d750fa8744fc18df2e30e.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             var layer_control_8569fecc05eb0f02bf1d49ba8f7847b4_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_00492a89143bc809e2c74e74345bb9aa,
#                     &quot;Mapbox Outdoors&quot; : tile_layer_496fccb7eb11e9ab995d57a8e594dd88,
#                     &quot;OS Maps&quot; : tile_layer_0008958ef016c8a8414353b502f4dd5c,
#                     &quot;OpenTopoMap&quot; : tile_layer_3d79495ed85d750fa8744fc18df2e30e,
#                 },
#                 overlays :  {
#                     &quot;macro_element_da0bf92d914e863f3b8c90a613e8eab0&quot; : geo_json_da0bf92d914e863f3b8c90a613e8eab0,
#                     &quot;macro_element_7d682379f4d204034060afcac78188c0&quot; : geo_json_7d682379f4d204034060afcac78188c0,
#                 },
#             };
#             let layer_control_8569fecc05eb0f02bf1d49ba8f7847b4 = L.control.layers(
#                 layer_control_8569fecc05eb0f02bf1d49ba8f7847b4_layers.base_layers,
#                 layer_control_8569fecc05eb0f02bf1d49ba8f7847b4_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#
#             tile_layer_00492a89143bc809e2c74e74345bb9aa.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             tile_layer_496fccb7eb11e9ab995d57a8e594dd88.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             tile_layer_0008958ef016c8a8414353b502f4dd5c.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             tile_layer_3d79495ed85d750fa8744fc18df2e30e.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             tile_layer_00492a89143bc809e2c74e74345bb9aa.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             tile_layer_496fccb7eb11e9ab995d57a8e594dd88.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             tile_layer_0008958ef016c8a8414353b502f4dd5c.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#             tile_layer_3d79495ed85d750fa8744fc18df2e30e.addTo(map_b2be4d472d0c3b002fab86626e58f917);
#
#
#
#         function geo_json_da0bf92d914e863f3b8c90a613e8eab0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_da0bf92d914e863f3b8c
